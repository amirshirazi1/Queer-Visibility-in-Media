# %%
# Import the requests library and API key
import pandas as pd
import requests
from config import tmdb_api_key

# %%
# Starting URL for TMDB API discover method including the API key from config.py. Using the language (English),
# region (US), release date start (01-01-2000) and end (12-31-2022), sort by (release date descending) parameters.
# Not included are the "page" and "certification" parameters which will be included in the function later below.
url = "https://api.themoviedb.org/3/discover/movie?api_key=" + tmdb_api_key + "&language=en-US&region=US&sort_by=primary_release_date.desc&certification_country=US&include_adult=false&include_video=false&primary_release_date.gte=2000-01-01&primary_release_date.lte=2022-12-31&with_original_language=en"

# %%
# Create a function that can take different URLs that you input to iterate through multiple pages of 
# the API call and to constrain the search to particular certification ratings. Specifying the params 
# for params with a dictionary containing the key/value pair for "page" and "certification".

def get_movies(url_name, page_num, rating):
    movies = requests.get(
        url_name,
        params={
            "page": page_num,
            "certification": rating}
    )
    # Create a variable to hold the JSON text of the 'get' request
    movies_data = movies.json()
    # Create a Pandas Dataframe for 'results' from the JSON dictionary
    return pd.DataFrame(movies_data['results'])

# %%
# Create a function that adds ratings into each individual rating dataframe.
def isolate_ratings(rating_df, rating):
    rating_df['rating'] = rating
    rating_df = rating_df.loc[:, ('id', 'rating')]
    return rating_df

# %%
# Create a function to get the additional movie information for every individual movie ID in the movies dataframe.

def get_info(movie_df):
    def gather_info(movie_url,id_list):
    #     Create a function to input each individual movie ID into the movie_id_url.
        def get_id_url(id_index):
            movie_id_url = "https://api.themoviedb.org/3/movie/" + str(id_list[id_index]) + "?api_key=" + tmdb_api_key
            return movie_id_url
    #     Create a list of movie URLs based on each movie's ID.
        movie_id_urls = [get_id_url(n) for n in range(len(id_list))]
        info_request = requests.get(movie_id_urls[movie_url])
        info_data = info_request.json()
        return pd.json_normalize(info_data)
    
    # Create a list of just the movie IDs so it can be called upon.
    id_list = movie_df['id'].tolist()
    
    # Get each movie's additional info by calling the function where n is the index of the ids list
    # and lgbts_ids is each movie's individual id.
    info = [gather_info(n, id_list) for n in range(len(id_list))]

    # Combine each movie's additional info dataframe into one.
    info_df = pd.concat(info)
    return info_df.reset_index().drop(columns='index')

# %%
# Create function that combines all individual rating dataframes into one.
# def combine_ratings(rating_df_list):
#     ratings_df = pd.concat(rating_df_list).set_index('id')
#     return ratings_df

def combine_clean_data(main_df, rating_df_list, info_df):
    
    # Create a nondestructive copy of the main_df
    movie_df = main_df.set_index('id')
    
    # Ensure that there are no "\r" substrings in the string of the "overview" column. This would cause formatting
    # issues when the dataframe is exported to a CSV
    movie_df['overview'] = movie_df['overview'].str.replace("\r", "")
    
    ratings_df = pd.concat(rating_df_list).set_index('id')
    movie_df = movie_df.join(ratings_df, on='id', how='left').reset_index()

    # Drop duplicates 
    movie_df = movie_df.drop_duplicates(subset=['id'], keep='last').reset_index().drop(columns='index')
    
    movie_df['rating'].fillna('NR', inplace=True)
    
    
    # Add genre names
    # Create genre_url variable
    genre_url = "https://api.themoviedb.org/3/genre/movie/list?api_key=" + tmdb_api_key + "&language=en-US"
    genre_request = requests.get(genre_url)
    genre_data = genre_request.json()
    genre_info = genre_data['genres']
    
    ids = [i['id'] for i in genre_info]
    names = [n['name'] for n in genre_info]
    
    genres_df = pd.DataFrame()
    genres_df[["id", "genres"]] = movie_df[['id','genre_ids']]
    sep_genres_df = pd.DataFrame(
        genres_df['genres'].to_list(), columns=['genre1', 'genre2', 'genre3', 'genre4', 'genre5', 'genre6'])
    
    sep_genres_df = sep_genres_df.replace(ids, names)
    sep_genres_df['genres'] = sep_genres_df.values.tolist()
    
    # Remove the null values from the list.
    sep_genres_df['genres'] = sep_genres_df.genres.apply(lambda x: [name for name in x if not pd.isnull(name)])
    
    # Drop individual genre columns.
    sep_genres_df = sep_genres_df.drop(columns=['genre1', 'genre2', 'genre3', 'genre4', 'genre5', 'genre6'])

    sep_genres_df['id'] = genres_df['id']
    sep_genres_df = sep_genres_df.set_index('id')
    
    # Join genres column from sep_genres_df into the main movie_df
    movie_df = movie_df.join(sep_genres_df, on='id', how='left')
    
    add_info_df = info_df[['id', 'budget', 'imdb_id', 'revenue', 'runtime', 'status']].set_index('id')
    movie_df = movie_df.join(add_info_df, on='id', how='left')
    
    # Reorder columns.
    new_columns = [
        'id', 'original_title', 'imdb_id', 'genre_ids', 'genres', 'rating', 'overview', 'popularity',
        'release_date','budget', 'revenue', 'runtime', 'status', 'title']
    return movie_df[new_columns]

# %%
# COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY 
# COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY COPY 



# Create function that combines all individual rating dataframes into one.
# def combine_ratings(rating_df_list):
#     ratings_df = pd.concat(rating_df_list).set_index('id')
#     return ratings_df

# def combine_clean_data(main_df, rating_df_list, info_df):


def join_ratings(main_df, rating_df_list):
    # Create a nondestructive copy of the main_df
    movie_df = main_df
    
    # Ensure that there are no "\r" substrings in the string of the "overview" column. This would cause formatting
    # issues when the dataframe is exported to a CSV
    movie_df['overview'] = movie_df['overview'].str.replace("\r", "")
    
    ratings_df = pd.concat(rating_df_list).set_index('id')
    movie_df = movie_df.join(ratings_df, on='id', how='left').reset_index()

    # Drop duplicates 
    movie_df = movie_df.drop_duplicates(subset=['id'], keep='last').reset_index().drop(columns='index')
    
    movie_df['rating'].fillna('NR', inplace=True)
    return movie_df
    

    
    
    
    
def get_genres(main_df):
    
    # Add genre names
    # Create genre_url variable
    
    genre_url = "https://api.themoviedb.org/3/genre/movie/list?api_key=" + tmdb_api_key + "&language=en-US"
    genre_request = requests.get(genre_url)
    genre_data = genre_request.json()
    genre_info = genre_data['genres']
    
    ids = [i['id'] for i in genre_info]
    names = [n['name'] for n in genre_info]
    
    genres_df = pd.DataFrame()
    genres_df[["id", "genres"]] = main_df[['id','genre_ids']]
#     movie_df = main_df.set_index('id')
    sep_genres_df = pd.DataFrame(
        genres_df['genres'].to_list(), columns=['genre1', 'genre2', 'genre3', 'genre4', 'genre5', 'genre6'])
    
    sep_genres_df['id'] = genres_df['id']
    sep_genres_df = sep_genres_df.set_index('id')
    sep_genres_df = sep_genres_df.replace(ids, names)
    sep_genres_df['genres'] = sep_genres_df.values.tolist()
    
    # Remove the null values from the list.
    sep_genres_df['genres'] = sep_genres_df.genres.apply(lambda x: [name for name in x if not pd.isnull(name)])
    sep_genres_df = sep_genres_df.drop(columns=['genre1', 'genre2', 'genre3', 'genre4', 'genre5', 'genre6'])
    
    # Join genres column from sep_genres_df into the main movie_df
    movie_df = main_df.join(sep_genres_df, how='left')
    return movie_df.reset_index()


#     add_info_df = info_df[['budget', 'imdb_id', 'revenue', 'runtime', 'status']].reset_index()
#     movie_df = movie_df.join(add_info_df, on='id', how='left')
    
#     # Reorder columns.
#     new_columns = [
#         'id', 'original_title', 'imdb_id', 'genre_ids', 'genres', 'rating', 'overview', 'popularity',
#         'release_date','budget', 'revenue', 'runtime', 'status', 'title']
#     return movie_df[new_columns]

# %%
# Create URL for movies tagged with keywords "LGBT, gay, lesbian, trans, transgender, and gay teen."
lgbt_url = url + "&with_keywords=158718%7C264384%7C264386%7C273637%7C290527%7C163037"

# %%
# The number of pages you want. (Note: the max number of pages for the ratings comes from the total amount of
# pages that the API call will iterate through to get all movies regardless of their certification rating).
pages_requested = 65

# Get all pages for each US rating as dataframes by calling the function "get_ratings()" 
# where "page_num" is variable n + 1. The list comprehension will iterate through the range 
# of "pages_requested" which is 12, adding 1 to each iteration to make the count 1-12. The get_ratings function
# uses the second variable to specify the rating needed in the URL parameter.
pages_lgbt = [get_movies(lgbt_url, n + 1, "") for n in range(pages_requested)]
pages_nr_lgbt = [get_movies(lgbt_url, n + 1, "NR") for n in range(pages_requested)]
pages_g_lgbt = [get_movies(lgbt_url, n + 1, "G") for n in range(pages_requested)]
pages_pg_lgbt = [get_movies(lgbt_url, n + 1, "PG") for n in range(pages_requested)]
pages_pg13_lgbt = [get_movies(lgbt_url, n + 1, "PG-13") for n in range(pages_requested)]
pages_r_lgbt = [get_movies(lgbt_url, n + 1, "R") for n in range(pages_requested)]
pages_nc17_lgbt = [get_movies(lgbt_url, n + 1, "NC-17") for n in range(pages_requested)]

# Combine the pages for each dataframe to single dataframe using the concat function (aka concatenate).
lgbt_movies_df = pd.concat(pages_lgbt)
nr_lgbt_df = pd.concat(pages_nr_lgbt)
g_lgbt_df = pd.concat(pages_g_lgbt) 
pg_lgbt_df = pd.concat(pages_pg_lgbt)
pg13_lgbt_df = pd.concat(pages_pg13_lgbt)
r_lgbt_df = pd.concat(pages_r_lgbt)
nc17_lgbt_df = pd.concat(pages_nc17_lgbt)

# %%
# Verify the length of each dataframe.
# (Note: there are no films in the G rating dataframe, meaning there are no LGBT films with a G rating.
# Therefore, g_lgbt_df will not be included in subsequent data wrangling).
print(len(nr_lgbt_df))
print(len(g_lgbt_df))
print(len(pg_lgbt_df))
print(len(pg13_lgbt_df))
print(len(r_lgbt_df))
print(len(nc17_lgbt_df))
# Out:
# 225
# 0
# 12
# 47
# 109
# 3

# %%
nr_lgbt_df = isolate_ratings(nr_lgbt_df, "NR")
pg_lgbt_df = isolate_ratings(pg_lgbt_df, "PG")
pg13_lgbt_df = isolate_ratings(pg13_lgbt_df, "PG-13")
r_lgbt_df = isolate_ratings(r_lgbt_df, "R")
nc17_lgbt_df = isolate_ratings(nc17_lgbt_df, "NC-17")

# %%
r_lgbt_df.head()
# Out:
#        id rating
# 0  876802      R
# 1  915164      R
# 2  857731      R
# 3  552269      R
# 4  591273      R

# %%
# # Create a list to store all the ratings dataframes.
# ratings_df_list = [nr_lgbt_df, g_lgbt_df,
#                    pg_lgbt_df, pg13_lgbt_df,
#                    r_lgbt_df, nc17_lgbt_df]

# %%
# # Create a list of just the movie IDs so it can be called upon.
# lgbt_ids = lgbt_movies_df['id'].tolist()

# # Get each movie's additional info by calling the functioon where n is the index of the ids list
# # and lgbts_ids is each movie's individual id.
# lgbt_info = [get_info(n, lgbt_ids) for n in range(len(lgbt_ids))]

# # Combine each movie's additional info dataframe into one.
# lgbt_info_df = pd.concat(lgbt_info)
lgbt_info_df = get_info(lgbt_movies_df)

# %%
# print(len(lgbt_info_df))
lgbt_info_df[['id', 'budget', 'imdb_id', 'revenue', 'runtime', 'status']].set_index('id')
# Out:
#         budget     imdb_id  revenue runtime           status
# id
# 507903       0   tt7775720        0       0    In Production
# 876802   20000  tt15470856        0       0    In Production
# 793992       0   tt5322004        0       0  Post Production
# 929477       0  tt17162546        0      19  Post Production
# 920345   20000        None        0      19         Released
# ...        ...         ...      ...     ...              ...
# 248757       0   tt0160710        0      91         Released
# 515728       0   tt0191181        0      18         Released
# 306484       0   tt1063334        0      25         Released
# 262942       0   tt0297034        0      69         Released
# 49156        0   tt0283033        0      37         Released
#
# [1299 rows x 5 columns]

# %%
print(len(lgbt_info_df))
lgbt_info_df[['id', 'budget', 'imdb_id', 'revenue', 'runtime', 'status']].set_index('id')
# Out:
# 1299
#         budget     imdb_id  revenue runtime           status
# id
# 507903       0   tt7775720        0       0    In Production
# 876802   20000  tt15470856        0       0    In Production
# 793992       0   tt5322004        0       0  Post Production
# 929477       0  tt17162546        0      19  Post Production
# 920345   20000        None        0      19         Released
# ...        ...         ...      ...     ...              ...
# 248757       0   tt0160710        0      91         Released
# 515728       0   tt0191181        0      18         Released
# 306484       0   tt1063334        0      25         Released
# 262942       0   tt0297034        0      69         Released
# 49156        0   tt0283033        0      37         Released
#
# [1299 rows x 5 columns]

# %%
test_df_ratings = join_ratings(lgbt_movies_df, [nr_lgbt_df, pg_lgbt_df, pg13_lgbt_df, r_lgbt_df, nc17_lgbt_df])

# %%
print(len(test_df_ratings))
test_df_ratings.head()
# Out:
# 1299
#    level_0  adult                     backdrop_path genre_ids      id  \
# 0        0  False                              None  [35, 18]  507903
# 1        1  False                              None  [27, 53]  876802
# 2        2  False                              None      [18]  793992
# 3        3  False                              None   [10749]  929477
# 4        4  False  /qQFvUg92Uh1jRXCNgqo9LduBDFD.jpg      [18]  920345
#
#   original_language                                original_title  \
# 0                en                                 Spoiler Alert
# 1                en                                   Saint Drogo
# 2                en                                  Three Months
# 3                en                                    Heart Shot
# 4                en  EMPATHY (Or: The Girl with The Pearled Hair)
#
#                                             overview  popularity  \
# 0  The story of Michael Ausiello and Kit Cowan's ...       3.248
# 1  Saint Drogo is a supernatural slowburn themati...       1.644
# 2  The story of Caleb, a South Florida teen who l...       1.464
# 3  Teenagers Nikki and Sam are in love and planni...       4.903
# 4  After running away from her emotionally abusiv...       2.928
#
#                         poster_path release_date  \
# 0  /np3y8wm2K7YK5RT6e68hw6IzhBw.jpg   2022-12-31
# 1  /ghq9XVBvmlbqrsKA7KDMsYOPjAu.jpg   2022-10-01
# 2  /AoMOVVkuVctRLyjfzjrEnPploxp.jpg   2022-02-23
# 3                              None   2022-02-17
# 4  /59C1l5dqtKuKuKy5qlE23PV4yC6.jpg   2022-01-25
#
#                                           title  video  vote_average  \
# 0                                 Spoiler Alert  False           0.0
# 1                                   Saint Drogo  False           0.0
# 2                                  Three Months  False           0.0
# 3                                    Heart Shot  False           0.0
# 4  EMPATHY (Or: The Girl with The Pearled Hair)  False           0.0
#
#    vote_count rating
# 0           0     NR
# 1           0      R
# 2           0     NR
# 3           0  PG-13
# 4           0     NR

# %%
test_df_ratings.loc[724:730]
# Out:
#      level_0  adult                     backdrop_path        genre_ids  \
# 724      724  False  /om54JgwkKYxJsgLve3y1ne7TExH.jpg         [35, 18]
# 725      726  False  /lkQ5ZZsCrQ1S7TOzujXM2Ct7NvZ.jpg  [18, 10749, 53]
# 726      727  False  /myYMBzPXgeZ3zPnYtyUB1dYvxgU.jpg             [18]
# 727      728  False                              None             [99]
# 728      729  False  /mSUnNIjJEkqkWxbklDjWCD2RUdy.jpg      [10749, 35]
# 729      730  False  /iFGpIJq7i3jAewxqJg8zihphUfN.jpg      [35, 10749]
# 730      731  False  /uWW6bLyvXt7TpHe6VYRneFficI7.jpg         [99, 35]
#
#          id original_language                original_title  \
# 724  156713                en                        C.O.G.
# 725  157370                en            Kill Your Darlings
# 726  221801                en              Naked as We Came
# 727  212849                en                       The Dog
# 728  212721                en                 Gerontophilia
# 729  216138                en  10 Rules for Sleeping Around
# 730  270698                en               I'm a Porn Star
#
#                                               overview  popularity  \
# 724  A gay cocky young man travels to Oregon to wor...       6.681
# 725  A murder in 1944 draws together the great poet...      15.979
# 726  Love, loss and hope are tumultuously explored ...       6.163
# 727  In 1972, John Wojtowicz attempted to rob a Bro...       2.986
# 728  Lake is in a straight relationship with Desire...       9.834
# 729  By following ten simple rules,  20-somethings ...       8.173
# 730  I'm a Porn Star follows the lives of guys in t...      14.795
#
#                           poster_path release_date  \
# 724  /sa0iJ5XAPZzxsZWo0fEoMjrujaZ.jpg   2013-09-20
# 725  /yswbLHDNm4gdbIk3DVEKT7Yzu4T.jpg   2013-10-16
# 726  /1OeU7vYojFopPUvh9wjNgUx1uhG.jpg   2013-09-13
# 727  /sgaFoabatyHxumdzTKSw6AAKdmQ.jpg   2014-08-05
# 728  /1TpLW6DWtsRHScA8bWe0AUNE7n5.jpg   2014-05-24
# 729  /dX8IMDXbVWJ7fq0AX0efog1SMX5.jpg   2014-04-04
# 730  /28ZqVlvpYJ1hEPuICiNsrZbDV3i.jpg   2013-10-04
#
#                             title  video  vote_average  vote_count rating
# 724                        C.O.G.  False           5.5          65      R
# 725            Kill Your Darlings  False           7.1        1148      R
# 726              Naked as We Came  False           5.7          31     NR
# 727                       The Dog  False           6.8          23     NR
# 728                 Gerontophilia  False           6.4          67     NR
# 729  10 Rules for Sleeping Around  False           3.6          46      R
# 730               I'm a Porn Star  False           5.6          17     NR

# %%
get_genres(test_df_ratings).loc[724:730]
# Out:
#      index      id  adult                     backdrop_path        genre_ids  \
# 724    724  156713  False  /om54JgwkKYxJsgLve3y1ne7TExH.jpg         [35, 18]
# 725    726  157370  False  /lkQ5ZZsCrQ1S7TOzujXM2Ct7NvZ.jpg  [18, 10749, 53]
# 726    727  221801  False  /myYMBzPXgeZ3zPnYtyUB1dYvxgU.jpg             [18]
# 727    728  212849  False                              None             [99]
# 728    729  212721  False  /mSUnNIjJEkqkWxbklDjWCD2RUdy.jpg      [10749, 35]
# 729    730  216138  False  /iFGpIJq7i3jAewxqJg8zihphUfN.jpg      [35, 10749]
# 730    731  270698  False  /uWW6bLyvXt7TpHe6VYRneFficI7.jpg         [99, 35]
#
#     original_language                original_title  \
# 724                en                        C.O.G.
# 725                en            Kill Your Darlings
# 726                en              Naked as We Came
# 727                en                       The Dog
# 728                en                 Gerontophilia
# 729                en  10 Rules for Sleeping Around
# 730                en               I'm a Porn Star
#
#                                               overview  popularity  \
# 724  A gay cocky young man travels to Oregon to wor...       6.681
# 725  A murder in 1944 draws together the great poet...      15.979
# 726  Love, loss and hope are tumultuously explored ...       6.163
# 727  In 1972, John Wojtowicz attempted to rob a Bro...       2.986
# 728  Lake is in a straight relationship with Desire...       9.834
# 729  By following ten simple rules,  20-somethings ...       8.173
# 730  I'm a Porn Star follows the lives of guys in t...      14.795
#
#                           poster_path release_date  \
# 724  /sa0iJ5XAPZzxsZWo0fEoMjrujaZ.jpg   2013-09-20
# 725  /yswbLHDNm4gdbIk3DVEKT7Yzu4T.jpg   2013-10-16
# 726  /1OeU7vYojFopPUvh9wjNgUx1uhG.jpg   2013-09-13
# 727  /sgaFoabatyHxumdzTKSw6AAKdmQ.jpg   2014-08-05
# 728  /1TpLW6DWtsRHScA8bWe0AUNE7n5.jpg   2014-05-24
# 729  /dX8IMDXbVWJ7fq0AX0efog1SMX5.jpg   2014-04-04
# 730  /28ZqVlvpYJ1hEPuICiNsrZbDV3i.jpg   2013-10-04
#
#                             title  video  vote_average  vote_count rating  \
# 724                        C.O.G.  False           5.5          65      R
# 725            Kill Your Darlings  False           7.1        1148      R
# 726              Naked as We Came  False           5.7          31     NR
# 727                       The Dog  False           6.8          23     NR
# 728                 Gerontophilia  False           6.4          67     NR
# 729  10 Rules for Sleeping Around  False           3.6          46      R
# 730               I'm a Porn Star  False           5.6          17     NR
#
#     genres
# 724    NaN
# 725    NaN
# 726    NaN
# 727    NaN
# 728    NaN
# 729    NaN
# 730    NaN

# %%
lgbt_movie_df = combine_clean_data(lgbt_movies_df, [nr_lgbt_df, pg_lgbt_df, pg13_lgbt_df, r_lgbt_df, nc17_lgbt_df], lgbt_info_df)

# %%
# Check to make sure items joined correctly.
print(len(lgbt_movie_df))
lgbt_movie_df.loc[lgbt_movie_df['title'] == "Rent"]
# Out:
# 1299
#           id original_title    imdb_id           genre_ids  \
# 260   557648           Rent  tt6881910  [10402, 10770, 18]
# 1115    1833           Rent  tt0294870         [18, 10749]
#
#                         genres rating  \
# 260   [Music, TV Movie, Drama]     NR
# 1115          [Drama, Romance]  PG-13
#
#                                                overview  popularity  \
# 260   The story of several friends in New York City ...       7.690
# 1115  This rock opera tells the story of one year in...      15.783
#
#      release_date    budget   revenue runtime    status title
# 260    2019-01-27         0         0     135  Released  Rent
# 1115   2005-11-17  40000000  31670620     135  Released  Rent

# %%
lgbt_movie_df.loc[724:730]
# Out:
#          id                original_title imdb_id        genre_ids  \
# 724  156713                        C.O.G.     NaN         [35, 18]
# 725  157370            Kill Your Darlings     NaN  [18, 10749, 53]
# 726  221801              Naked as We Came     NaN             [18]
# 727  212849                       The Dog     NaN             [99]
# 728  212721                 Gerontophilia     NaN      [10749, 35]
# 729  216138  10 Rules for Sleeping Around     NaN      [35, 10749]
# 730  270698               I'm a Porn Star     NaN         [99, 35]
#
#                          genres rating  \
# 724             [Comedy, Drama]      R
# 725  [Drama, Romance, Thriller]      R
# 726                     [Drama]     NR
# 727               [Documentary]     NR
# 728           [Romance, Comedy]     NR
# 729           [Comedy, Romance]      R
# 730       [Documentary, Comedy]     NR
#
#                                               overview  popularity  \
# 724  A gay cocky young man travels to Oregon to wor...       6.681
# 725  A murder in 1944 draws together the great poet...      15.979
# 726  Love, loss and hope are tumultuously explored ...       6.163
# 727  In 1972, John Wojtowicz attempted to rob a Bro...       2.986
# 728  Lake is in a straight relationship with Desire...       9.834
# 729  By following ten simple rules,  20-somethings ...       8.173
# 730  I'm a Porn Star follows the lives of guys in t...      14.795
#
#     release_date  budget  revenue runtime status                         title
# 724   2013-09-20     NaN      NaN     NaN    NaN                        C.O.G.
# 725   2013-10-16     NaN      NaN     NaN    NaN            Kill Your Darlings
# 726   2013-09-13     NaN      NaN     NaN    NaN              Naked as We Came
# 727   2014-08-05     NaN      NaN     NaN    NaN                       The Dog
# 728   2014-05-24     NaN      NaN     NaN    NaN                 Gerontophilia
# 729   2014-04-04     NaN      NaN     NaN    NaN  10 Rules for Sleeping Around
# 730   2013-10-04     NaN      NaN     NaN    NaN               I'm a Porn Star

# %%
lgbt_movies_df.reset_index().loc[724:730]
# Out:
#      index  adult                     backdrop_path        genre_ids      id  \
# 724      4  False  /om54JgwkKYxJsgLve3y1ne7TExH.jpg         [35, 18]  156713
# 725      5  False  /lkQ5ZZsCrQ1S7TOzujXM2Ct7NvZ.jpg  [18, 10749, 53]  157370
# 726      6  False  /myYMBzPXgeZ3zPnYtyUB1dYvxgU.jpg             [18]  221801
# 727      7  False                              None             [99]  212849
# 728      8  False  /mSUnNIjJEkqkWxbklDjWCD2RUdy.jpg      [10749, 35]  212721
# 729      9  False  /iFGpIJq7i3jAewxqJg8zihphUfN.jpg      [35, 10749]  216138
# 730     10  False  /uWW6bLyvXt7TpHe6VYRneFficI7.jpg         [99, 35]  270698
#
#     original_language                original_title  \
# 724                en                        C.O.G.
# 725                en            Kill Your Darlings
# 726                en              Naked as We Came
# 727                en                       The Dog
# 728                en                 Gerontophilia
# 729                en  10 Rules for Sleeping Around
# 730                en               I'm a Porn Star
#
#                                               overview  popularity  \
# 724  A gay cocky young man travels to Oregon to wor...       6.681
# 725  A murder in 1944 draws together the great poet...      15.979
# 726  Love, loss and hope are tumultuously explored ...       6.163
# 727  In 1972, John Wojtowicz attempted to rob a Bro...       2.986
# 728  Lake is in a straight relationship with Desire...       9.834
# 729  By following ten simple rules,  20-somethings ...       8.173
# 730  I'm a Porn Star follows the lives of guys in t...      14.795
#
#                           poster_path release_date  \
# 724  /sa0iJ5XAPZzxsZWo0fEoMjrujaZ.jpg   2013-09-20
# 725  /yswbLHDNm4gdbIk3DVEKT7Yzu4T.jpg   2013-10-16
# 726  /1OeU7vYojFopPUvh9wjNgUx1uhG.jpg   2013-09-13
# 727  /sgaFoabatyHxumdzTKSw6AAKdmQ.jpg   2014-08-05
# 728  /1TpLW6DWtsRHScA8bWe0AUNE7n5.jpg   2014-05-24
# 729  /dX8IMDXbVWJ7fq0AX0efog1SMX5.jpg   2014-04-04
# 730  /28ZqVlvpYJ1hEPuICiNsrZbDV3i.jpg   2013-10-04
#
#                             title  video  vote_average  vote_count  \
# 724                        C.O.G.  False           5.5          65
# 725            Kill Your Darlings  False           7.1        1148
# 726              Naked as We Came  False           5.7          31
# 727                       The Dog  False           6.8          23
# 728                 Gerontophilia  False           6.4          67
# 729  10 Rules for Sleeping Around  False           3.6          46
# 730               I'm a Porn Star  False           5.6          17
#
#                            genre
# 724                      [Drama]
# 725              [Drama, Comedy]
# 726                      [Drama]
# 727                [Documentary]
# 728                      [Drama]
# 729              [Comedy, Drama]
# 730  [Thriller, Horror, Mystery]

# %%
test.loc[[724:730]]
# Out:
#   File "<ipython-input-162-bc91630e1ca2>", line 1
#     test.loc[[724:730]]
#                  ^
# SyntaxError: invalid syntax

# %%
lgbt_movie_df[lgbt_movie_df.title.duplicated()]
# Out:
#           id original_title    imdb_id        genre_ids  \
# 438   490232            Ace  tt7176320               []
# 845   665061          Pride  tt1727252             [35]
# 896   356753           AWOL  tt1762363             [18]
# 928   753451      Remission  tt1655387             [27]
# 1116    1833           Rent  tt0424496      [18, 10749]
# 1128   49113           Dare  tt0446051             [18]
# 1230  178516       D.E.B.S.  tt0314039  [35, 28, 10749]
#
#                                           genre rating  \
# 438                                          []     NR
# 845                            [Comedy, Horror]     NR
# 896                            [Drama, Mystery]     NR
# 928                  [Romance, Science Fiction]     NR
# 1116                              [Documentary]  PG-13
# 1128  [Action, Crime, Drama, Mystery, Thriller]     NR
# 1230                          [Drama, Thriller]     NR
#
#                                                overview  popularity  \
# 438   An unlikely pair of teenagers perform an awkwa...       0.877
# 845   On the morning of his annual gay pride party, ...       1.165
# 896   Days before deployment to Afghanistan, Joey re...       0.994
# 928   Sam is waiting for a doctor's results of his l...       0.600
# 1116  This rock opera tells the story of one year in...      15.783
# 1128  High school senior Ben secretly lusts after ba...       3.287
# 1230  A quartet of girls from a prep high school are...       2.406
#
#      release_date  budget  revenue runtime    status      title
# 438    2017-04-30     0.0      0.0    None  Released        Ace
# 845    2011-10-22     0.0      0.0     120  Released      Pride
# 896    2011-01-21     0.0      0.0      14  Released       AWOL
# 928    2010-04-16     0.0      0.0      93  Released  Remission
# 1116   2005-11-17     0.0  19738.0      95  Released       Rent
# 1128   2005-08-13     0.0      0.0      98  Released       Dare
# 1230   2003-01-16     0.0      0.0     114  Released   D.E.B.S.

# %%
# Create genre_url variable
# genre_url = "https://api.themoviedb.org/3/genre/movie/list?api_key=" + tmdb_api_key + "&language=en-US"

# %%
def get_genres(genre_url):
    genre_request = requests.get(genre_url)
    genre_data = genre_request.json()
    genre_info = genre_data['genres']
    return genre_info
ids = [i['id'] for i in get_genres(genre_url)]
names = [n['name'] for n in get_genres(genre_url)]

# %%
ids = [i['id'] for i in get_genres(genre_url)]
names = [n['name'] for n in get_genres(genre_url)]

print(ids)
print(names)
# Out:
# [28, 12, 16, 35, 80, 99, 18, 10751, 14, 36, 27, 10402, 9648, 10749, 878, 10770, 53, 10752, 37]
# ['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Mystery', 'Romance', 'Science Fiction', 'TV Movie', 'Thriller', 'War', 'Western']

# %%
add_genre_names(lgbt_movies_df, genre_url)
# Out:
#     adult                     backdrop_path    genre_ids      id  \
# 0   False                              None     [35, 18]  507903
# 1   False                              None     [27, 53]  876802
# 2   False                              None         [18]  793992
# 3   False                              None      [10749]  929477
# 4   False  /qQFvUg92Uh1jRXCNgqo9LduBDFD.jpg         [18]  920345
# ..    ...                               ...          ...     ...
# 13  False  /ti0VLq5Xv8PicnLAfcrnFmNsYmY.jpg  [35, 10749]  248757
# 14  False  /dD90r6NQ8cFgYjjYGSLRQLCdJWN.jpg         [18]  515728
# 15  False  /n6kR7P93mUNj70zSdQLOWtExbyw.jpg           []  306484
# 16  False                              None         [99]  262942
# 17  False  /yPqdmvQ8jgi99w5zBJ4rnBBnmQA.jpg           []   49156
#
#    original_language                                original_title  \
# 0                 en                                 Spoiler Alert
# 1                 en                                   Saint Drogo
# 2                 en                                  Three Months
# 3                 en                                    Heart Shot
# 4                 en  EMPATHY (Or: The Girl with The Pearled Hair)
# ..               ...                                           ...
# 13                en                                         Punks
# 14                en                                         Hitch
# 15                en                                  Meet Joe Gay
# 16                en                               A Boy Named Sue
# 17                en                                      Take-out
#
#                                              overview  popularity  \
# 0   The story of Michael Ausiello and Kit Cowan's ...       3.248
# 1   Saint Drogo is a supernatural slowburn themati...       1.644
# 2   The story of Caleb, a South Florida teen who l...       1.464
# 3   Teenagers Nikki and Sam are in love and planni...       4.903
# 4   After running away from her emotionally abusiv...       2.928
# ..                                                ...         ...
# 13  In his directorial debut, Patrik-Ian Polk chro...       1.303
# 14  Two friends are on a road trip and a one-sided...       1.790
# 15  Director Benjamin Morgan takes a hard look at ...       1.181
# 16  A Boy Named Sue chronicles the transformation ...       1.583
# 17  The film is the coming-of-age story of the chi...       0.600
#
#                          poster_path release_date  \
# 0   /np3y8wm2K7YK5RT6e68hw6IzhBw.jpg   2022-12-31
# 1   /ghq9XVBvmlbqrsKA7KDMsYOPjAu.jpg   2022-10-01
# 2   /AoMOVVkuVctRLyjfzjrEnPploxp.jpg   2022-02-23
# 3                               None   2022-02-17
# 4   /59C1l5dqtKuKuKy5qlE23PV4yC6.jpg   2022-01-25
# ..                               ...          ...
# 13  /3an3l9X95zTx8vtzxqYMhCxuBOz.jpg   2000-01-24
# 14  /4kH0kEKmrDtxxJh0rSUtecJYOpK.jpg   2000-01-01
# 15  /pJYcgatiDE6eYwvO25baVoDkb0a.jpg   2000-01-01
# 16  /9uTNEluw8FAos3trAXqE7ffllZq.jpg   2000-01-01
# 17  /rhI5W03wPFkp74R4Ut5qq4XlOCH.jpg   2000-01-01
#
#                                            title  video  vote_average  \
# 0                                  Spoiler Alert  False           0.0
# 1                                    Saint Drogo  False           0.0
# 2                                   Three Months  False           0.0
# 3                                     Heart Shot  False           0.0
# 4   EMPATHY (Or: The Girl with The Pearled Hair)  False           0.0
# ..                                           ...    ...           ...
# 13                                         Punks  False           4.7
# 14                                         Hitch  False           5.1
# 15                                  Meet Joe Gay  False           4.0
# 16                               A Boy Named Sue  False           3.0
# 17                                      Take-out  False           3.5
#
#     vote_count                     genre
# 0            0           [Comedy, Drama]
# 1            0        [Horror, Thriller]
# 2            0                   [Drama]
# 3            0                 [Romance]
# 4            0                   [Drama]
# ..         ...                       ...
# 13           6             [Documentary]
# 14           8  [Romance, Comedy, Drama]
# 15           5         [Romance, Comedy]
# 16           2             [Documentary]
# 17           2          [Drama, Romance]
#
# [1298 rows x 15 columns]

# %%
# Create function to add genre names
def add_genre_names(main_df):
     genres_df = pd.DataFrame()
    genres_df['genre'] = main_df['genre_ids']
    genres_df = pd.DataFrame(
        genres_df['genre'].to_list(), columns=['genre1', 'genre2', 'genre3', 'genre4', 'genre5', 'genre6'])
    def get_genres(url_for_genres):
        genre_request = requests.get(url_for_genres)
        genre_data = genre_request.json()
        genre_info = genre_data['genres']
        return genre_info
    ids = [i['id'] for i in get_genres(genre_url)]
    names = [n['name'] for n in get_genres(genre_url)]
    genres_df = genres_df.replace(ids, names)
    genres_df['genres'] = genres_df.values.tolist()
    genres_df['genres'] = genres_df.genres.apply(lambda x: [genre for genre in x if not pd.isnull(genre)])
    main_df['genre'] = genres_df['genres']
    return main_df

# %%
add_genre_names(lgbt_movies_df)
# Out:
#     adult                     backdrop_path    genre_ids      id  \
# 0   False                              None     [35, 18]  507903
# 1   False                              None     [27, 53]  876802
# 2   False                              None         [18]  793992
# 3   False                              None      [10749]  929477
# 4   False  /qQFvUg92Uh1jRXCNgqo9LduBDFD.jpg         [18]  920345
# ..    ...                               ...          ...     ...
# 13  False  /ti0VLq5Xv8PicnLAfcrnFmNsYmY.jpg  [35, 10749]  248757
# 14  False  /dD90r6NQ8cFgYjjYGSLRQLCdJWN.jpg         [18]  515728
# 15  False  /n6kR7P93mUNj70zSdQLOWtExbyw.jpg           []  306484
# 16  False                              None         [99]  262942
# 17  False  /yPqdmvQ8jgi99w5zBJ4rnBBnmQA.jpg           []   49156
#
#    original_language                                original_title  \
# 0                 en                                 Spoiler Alert
# 1                 en                                   Saint Drogo
# 2                 en                                  Three Months
# 3                 en                                    Heart Shot
# 4                 en  EMPATHY (Or: The Girl with The Pearled Hair)
# ..               ...                                           ...
# 13                en                                         Punks
# 14                en                                         Hitch
# 15                en                                  Meet Joe Gay
# 16                en                               A Boy Named Sue
# 17                en                                      Take-out
#
#                                              overview  popularity  \
# 0   The story of Michael Ausiello and Kit Cowan's ...       3.248
# 1   Saint Drogo is a supernatural slowburn themati...       1.644
# 2   The story of Caleb, a South Florida teen who l...       1.464
# 3   Teenagers Nikki and Sam are in love and planni...       4.903
# 4   After running away from her emotionally abusiv...       2.928
# ..                                                ...         ...
# 13  In his directorial debut, Patrik-Ian Polk chro...       1.303
# 14  Two friends are on a road trip and a one-sided...       1.790
# 15  Director Benjamin Morgan takes a hard look at ...       1.181
# 16  A Boy Named Sue chronicles the transformation ...       1.583
# 17  The film is the coming-of-age story of the chi...       0.600
#
#                          poster_path release_date  \
# 0   /np3y8wm2K7YK5RT6e68hw6IzhBw.jpg   2022-12-31
# 1   /ghq9XVBvmlbqrsKA7KDMsYOPjAu.jpg   2022-10-01
# 2   /AoMOVVkuVctRLyjfzjrEnPploxp.jpg   2022-02-23
# 3                               None   2022-02-17
# 4   /59C1l5dqtKuKuKy5qlE23PV4yC6.jpg   2022-01-25
# ..                               ...          ...
# 13  /3an3l9X95zTx8vtzxqYMhCxuBOz.jpg   2000-01-24
# 14  /4kH0kEKmrDtxxJh0rSUtecJYOpK.jpg   2000-01-01
# 15  /pJYcgatiDE6eYwvO25baVoDkb0a.jpg   2000-01-01
# 16  /9uTNEluw8FAos3trAXqE7ffllZq.jpg   2000-01-01
# 17  /rhI5W03wPFkp74R4Ut5qq4XlOCH.jpg   2000-01-01
#
#                                            title  video  vote_average  \
# 0                                  Spoiler Alert  False           0.0
# 1                                    Saint Drogo  False           0.0
# 2                                   Three Months  False           0.0
# 3                                     Heart Shot  False           0.0
# 4   EMPATHY (Or: The Girl with The Pearled Hair)  False           0.0
# ..                                           ...    ...           ...
# 13                                         Punks  False           4.7
# 14                                         Hitch  False           5.1
# 15                                  Meet Joe Gay  False           4.0
# 16                               A Boy Named Sue  False           3.0
# 17                                      Take-out  False           3.5
#
#     vote_count                     genre
# 0            0           [Comedy, Drama]
# 1            0        [Horror, Thriller]
# 2            0                   [Drama]
# 3            0                 [Romance]
# 4            0                   [Drama]
# ..         ...                       ...
# 13           6             [Documentary]
# 14           8  [Romance, Comedy, Drama]
# 15           5         [Romance, Comedy]
# 16           2             [Documentary]
# 17           2          [Drama, Romance]
#
# [1298 rows x 15 columns]

# %%
# Create function that combines all individual rating dataframes into one.
# def combine_ratings(rating_df_list):
#     ratings_df = pd.concat(rating_df_list).set_index('id')
#     return ratings_df

def combining_data(main_df, rating_df_list, info_df):
    # Reorder columns.
    new_columns = [
        'id', 'original_title', 'imdb_id', 'genre_ids',
        'genre', 'rating',
        'overview', 'popularity', 'release_date','budget',
        'revenue', 'runtime', 'status', 'title']
    main_df = main_df.set_index('id')
    def combine_ratings(rating_df_list):
        ratings_df = pd.concat(rating_df_list).set_index('id')
        return ratings_df
    
    # Create function to add genre names
    def add_genre_names(main_df):
        # Create genre_url variable
        genre_url = "https://api.themoviedb.org/3/genre/movie/list?api_key=" + tmdb_api_key + "&language=en-US"
        genres_df = pd.DataFrame()
        genres_df['genre'] = main_df['genre_ids']
        genres_df = pd.DataFrame(
        genres_df['genre'].to_list(), columns=['genre1', 'genre2', 'genre3', 'genre4', 'genre5', 'genre6'])
        def get_genres(url_for_genres):
            genre_request = requests.get(url_for_genres)
            genre_data = genre_request.json()
            genre_info = genre_data['genres']
            return genre_info
        ids = [i['id'] for i in get_genres(genre_url)]
        names = [n['name'] for n in get_genres(genre_url)]
        genres_df = genres_df.replace(ids, names)
        genres_df['genres'] = genres_df.values.tolist()
        genres_df['genres'] = genres_df.genres.apply(lambda x: [genre for genre in x if not pd.isnull(genre)])
        main_df['genre'] = genres_df['genres']
        return main_df
    
    main_df = main_df.join(ratings_df, on='id', how='left').reset_index()
    main_df['rating'].fillna('NR', inplace=True)
    main_df = main_df.join(info_df, how='left')
    main_df = main_df[new_columns]
    return main_df

# %%
nc17_lgbt_df = isolate_ratings(nc17_lgbt_df, "NC-17")
r_lgbt_df = isolate_ratings(r_lgbt_df, "R")

# %%
lgbt_ratings_df = combine_ratings([r_lgbt_df, nc17_lgbt_df])

# %%
lgbt_ratings_df
# Out:
#        rating
# id
# 876802      R
# 915164      R
# 857731      R
# 552269      R
# 591273      R
# ...       ...
# 95048       R
# 22597       R
# 526034  NC-17
# 94025   NC-17
# 1378    NC-17
#
# [111 rows x 1 columns]

# %%
r_lgbt_df.head()
# Out:
#        id rating
# 0  876802      R
# 1  915164      R
# 2  857731      R
# 3  552269      R
# 4  591273      R

# %%
[ratings[ratings[n] for n in range(len(ratings))]]
# Out:
#   File "<ipython-input-14-cc956e510930>", line 1
#     [ratings[ratings[n] for n in range(len(ratings))]]
#                           ^
# SyntaxError: invalid syntax

# %%
ratings = ["NR", "G", "PG", "PG-13", "R", "NC-17"]
